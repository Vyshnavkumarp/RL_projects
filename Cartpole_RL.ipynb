# %% [markdown]
# # 1 Import dependencies

# %%
# !pip install stable-baselines3[extra]
# !pip install gymnasium
# Out:
# Requirement already satisfied: stable-baselines3[extra] in d:\anaconda_3\lib\site-packages (2.2.1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (1.24.3)
# Requirement already satisfied: torch>=1.13 in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: cloudpickle in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: matplotlib in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (3.7.2)
# Collecting opencv-python (from stable-baselines3[extra])
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pygame (from stable-baselines3[extra])
#   Obtaining dependency information for pygame from https://files.pythonhosted.org/packages/82/61/93ae7afbd931a70510cfdf0a7bb0007540020b8d80bc1d8762ebdc46479b/pygame-2.5.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached pygame-2.5.2-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: tensorboard>=2.9.1 in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (2.15.2)
# Requirement already satisfied: psutil in c:\users\vyshn\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (5.9.8)
# Requirement already satisfied: tqdm in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (4.65.0)
# Collecting rich (from stable-baselines3[extra])
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/be/be/1520178fa01eabe014b16e72a952b9f900631142ccd03dc36cf93e30c1ce/rich-13.7.0-py3-none-any.whl.metadata
#   Using cached rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting shimmy[atari]~=1.3.0 (from stable-baselines3[extra])
#   Obtaining dependency information for shimmy[atari]~=1.3.0 from https://files.pythonhosted.org/packages/dc/f9/07ef16463db14ac1b30f149c379760f5cacf3fc677b295d29a92f3127914/Shimmy-1.3.0-py3-none-any.whl.metadata
#   Using cached Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in d:\anaconda_3\lib\site-packages (from stable-baselines3[extra]) (10.0.1)
# Collecting autorom[accept-rom-license]~=0.6.1 (from stable-baselines3[extra])
#   Using cached AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: click in d:\anaconda_3\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in d:\anaconda_3\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra])
#   Using cached AutoROM.accept_rom_license-0.6.1-py3-none-any.whl
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\anaconda_3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\anaconda_3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0->stable-baselines3[extra])
#   Using cached ale_py-0.8.1-cp311-cp311-win_amd64.whl (952 kB)
# Requirement already satisfied: absl-py>=0.4 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.60.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.2)
# Requirement already satisfied: setuptools>=41.0.0 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\users\vyshn\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda_3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: filelock in d:\anaconda_3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.9.0)
# Requirement already satisfied: sympy in d:\anaconda_3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in d:\anaconda_3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in d:\anaconda_3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: fsspec in d:\anaconda_3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2023.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda_3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda_3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda_3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda_3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vyshn\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\anaconda_3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vyshn\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda_3\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda_3\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda_3\lib\site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vyshn\appdata\roaming\python\python311\site-packages (from rich->stable-baselines3[extra]) (2.17.2)
# Requirement already satisfied: colorama in c:\users\vyshn\appdata\roaming\python\python311\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable-baselines3[extra])
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/93/e8/facde510585869b5ec694e8e0363ffe4eba067cb357a8398a55f6a1f8023/importlib_resources-6.1.1-py3-none-any.whl.metadata
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda_3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda_3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda_3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda_3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda_3\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda_3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda_3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda_3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda_3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda_3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda_3\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda_3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda_3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached pygame-2.5.2-cp311-cp311-win_amd64.whl (10.8 MB)
# Using cached rich-13.7.0-py3-none-any.whl (240 kB)
# Using cached Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Installing collected packages: pygame, opencv-python, importlib-resources, shimmy, rich, AutoROM.accept-rom-license, autorom, ale-py
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 importlib-resources-6.1.1 opencv-python-4.9.0.80 pygame-2.5.2 rich-13.7.0 shimmy-1.3.0

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "CartPole-v1"
env = gym.make(environment_name, render_mode="human")

# %%
episodes = 5
for episode in range(1, episodes + 1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, truncated, info = env.step(action)
        score += reward
    print("Episode: {}, Score: {}".format(episode, score))
env.close()
# Out:
# Episode: 1, Score: 23.0
# Episode: 2, Score: 31.0
# Episode: 3, Score: 25.0
# Episode: 4, Score: 52.0
# Episode: 5, Score: 47.0

# %% [markdown]
# ### Shows random actions

# %%
env.action_space.sample()
# Out:
# 1

# %% [markdown]
# ### Displays observation of the space

# %%
env.observation_space.sample()
# Out:
# array([-4.7542429e+00, -1.6298754e+38, -3.7188858e-01, -2.6541647e+37],
#       dtype=float32)

# %% [markdown]
# ### Creating a path to store the tensorboard log of the training

# %%
log_path = os.path.join('C://', 'Users', 'vyshn', 'Documents System', '6th Sem', 'RL', 'RL_Projects', 'Training', 'Logs')

# %%
log_path
# Out:
# 'C:Users\\vyshn\\Documents System\\6th Sem\\RL\\RL_Projects\\Training\\Logs'

# %% [markdown]
# ### Setting up dummy vector environment

# %%
env = gym.make(environment_name, render_mode = "human")
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cpu device

# %% [markdown]
# ### Training the model

# %%
model.learn(total_timesteps = 20000)
# Out:
# Logging to C:Users\vyshn\Documents System\6th Sem\RL\RL_Projects\Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 521  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009878541 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00231     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.08        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 51.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010290162 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0896      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 37          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 4           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007914957 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 52.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008026738 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 62.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 6            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0072255237 |
# |    clip_fraction        | 0.0796       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 0.412        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.7         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0168      |
# |    value_loss           | 60.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 7            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0062515875 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.584       |
# |    explained_variance   | 0.345        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 76.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 8           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006170671 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0096     |
# |    value_loss           | 59.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 9           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005975144 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.8         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 46.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 10           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0043664835 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.541       |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.78         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00478     |
# |    value_loss           | 45.3         |
# ------------------------------------------

# %% [markdown]
# ### Setting up path for storing the model

# %%
PPO_path = os.path.join('C:', 'Users', 'vyshn', 'Documents System', '6th Sem', 'RL', 'RL_Projects', 'Training', 'Saved Models', 'PPO_Model_Cartpole.zip')

# %%
model.save(PPO_path)
# Out:
# D:\Anaconda_3\Lib\site-packages\stable_baselines3\common\save_util.py:283: UserWarning: Path 'C:Users\vyshn\Documents System\6th Sem\RL\RL_Projects\Training\Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
del model

# %% [markdown]
# ### Reloading the model from saved path

# %%
model = PPO.load(PPO_path, env = env)

# %% [markdown]
# ### Evaluating the model's performance

# %%
#Evaluation
evaluate_policy(model, env, n_eval_episodes = 10, render = True)
# Out:
# D:\Anaconda_3\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (500.0, 0.0)

# %% [markdown]
# ### Closing the env

# %%
env.close()

# %%
# Observation space
env.reset()[0]
# Out:
# array([ 0.0273257 ,  0.04699913,  0.01946591, -0.02997928], dtype=float32)

# %% [markdown]
# ### Gameplay by the PPO Model

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([-1.4361699 , -0.03888802,  0.03800402, -0.05264218], dtype=float32)}]

# %% [markdown]
# ### Playing for 5 episodes

# %%
episodes = 5
for episode in range(1, episodes + 1):
    obs  = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print("Episode: {}, Score: {}".format(episode, score))
env.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 9
#       7 while not done:
#       8     env.render()
# ----> 9     action, _states = model.predict(obs)
#      10     obs, reward, done, info = env.step(action)
#      11     score += reward
#
# File D:\Anaconda_3\Lib\site-packages\stable_baselines3\common\base_class.py:553, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     533 def predict(
#     534     self,
#     535     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     538     deterministic: bool = False,
#     539 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     540     """
#     541     Get the policy action from an observation (and optional hidden state).
#     542     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     551         (used in recurrent policies)
#     552     """
# --> 553     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File D:\Anaconda_3\Lib\site-packages\stable_baselines3\common\policies.py:355, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     352 # Check for common mistake that the user does not mix Gym/VecEnv API
#     353 # Tuple obs are not supported by SB3, so we can safely do that check
#     354 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
# --> 355     raise ValueError(
#     356         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     357         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#     358         "vs `obs = vec_env.reset()` (SB3 VecEnv). "
#     359         "See related issue https://github.com/DLR-RM/stable-baselines3/issues/1694 "
#     360         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     361     )
#     363 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     365 with th.no_grad():
#
# ValueError: You have passed a tuple to the predict() function instead of a Numpy array or a Dict. You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) vs `obs = vec_env.reset()` (SB3 VecEnv). See related issue https://github.com/DLR-RM/stable-baselines3/issues/1694 and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api

# %%
# !pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in c:\users\vyshn\anaconda3\lib\site-packages (2.15.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (1.24.3)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (4.23.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\vyshn\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vyshn\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\vyshn\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\vyshn\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vyshn\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vyshn\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vyshn\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vyshn\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vyshn\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\vyshn\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\vyshn\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard) (3.2.2)

# %% [markdown]
# # Viewing logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_5')

# %%
training_log_path
# Out:
# 'C:Users\\vyshn\\Documents System\\6th Sem\\RL\\RL_Projects\\Training\\Logs\\PPO_5'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# 2024-02-14 12:30:34.321865: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:tensorflow:From D:\Anaconda_3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# usage: tensorboard [-h] [--helpfull] [--logdir PATH] [--logdir_spec PATH_SPEC]
#                    [--host ADDR] [--bind_all] [--port PORT]
#                    [--reuse_port BOOL] [--load_fast {false,auto,true}]
#                    [--extra_data_server_flags EXTRA_DATA_SERVER_FLAGS]
#                    [--grpc_creds_type {local,ssl,ssl_dev}]
#                    [--grpc_data_provider PORT] [--purge_orphaned_data BOOL]
#                    [--db URI] [--db_import] [--inspect] [--version_tb]
#                    [--tag TAG] [--event_file PATH] [--path_prefix PATH]
#                    [--window_title TEXT] [--max_reload_threads COUNT]
#                    [--reload_interval SECONDS] [--reload_task TYPE]
#                    [--reload_multifile BOOL]
#                    [--reload_multifile_inactive_secs SECONDS]
#                    [--generic_data TYPE]
#                    [--samples_per_plugin SAMPLES_PER_PLUGIN]
#                    [--detect_file_replacement BOOL]
#                    {serve,dev} ...
# tensorboard: error: argument {serve,dev}: invalid choice: 'System\\6th' (choose from 'serve', 'dev')

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/93/21/9b035a4f823d6aee2917c75415be9a95861ff3d73a0a65e48edbf210cec1/tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting tensorflow-intel==2.15.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-intel==2.15.0 from https://files.pythonhosted.org/packages/4c/48/1a5a15517f18eaa4ff8d598b1c000300b20c1bb0e624539d702117a0c369/tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for flatbuffers>=23.5.26 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.9.0)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/02/8c/dc970bc00867fe290e8c8a7befa1635af716a9ebdfe3fb9dce0ca4b522ce/libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata
#   Downloading libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for ml-dtypes~=0.2.0 from https://files.pythonhosted.org/packages/08/89/c727fde1a3d12586e0b8c01abf53754707d76beaa9987640e70807d4545f/ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.24.3)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: packaging in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for termcolor>=1.1.0 from https://files.pythonhosted.org/packages/d9/5f/8c716e47b3a50cbd7c146f45881e11d9414def768b7cd9c5e6650ec2a80a/termcolor-2.4.0-py3-none-any.whl.metadata
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl (1.5 MB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.16,>=2.15.0 from https://files.pythonhosted.org/packages/b6/c8/2f823c8958d5342eafc6dd3e922f0cc4fcf8c2e0460284cc462dae3b60a0/tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for keras<2.16,>=2.15.0 from https://files.pythonhosted.org/packages/fc/a7/0d4490de967a67f68a538cc9cdb259bff971c4b5787f7765dc7c8f118f71/keras-2.15.0-py3-none-any.whl.metadata
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vyshn\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vyshn\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\vyshn\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vyshn\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\vyshn\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\vyshn\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vyshn\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vyshn\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vyshn\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vyshn\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vyshn\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\vyshn\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\vyshn\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Using cached tensorflow-2.15.0-cp311-cp311-win_amd64.whl (2.1 kB)
# Using cached tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl (300.9 MB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
# Using cached ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl (938 kB)
# Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, opt-einsum, ml-dtypes, keras, google-pasta, gast, astunparse, tensorflow-intel, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-23.5.26 gast-0.5.4 google-pasta-0.2.0 keras-2.15.0 libclang-16.0.6 ml-dtypes-0.2.0 opt-einsum-3.3.0 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0

# %% [markdown]
# # Adding a Callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('D:', 'RL', 'Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold = 600, verbose = 1)
eval_callback = EvalCallback(env,
                            callback_on_new_best = stop_callback,
                            eval_freq = 10000,
                            best_model_save_path = save_path,
                            verbose = 1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cpu device

# %% [markdown]
# MlpPolicy is a type of policy network that uses a multi-layer perceptron (MLP) to extract features from the observations and output actions and values

# %%
model.learn(total_timesteps = 20000, callback = eval_callback)
# Out:
# Logging to D:RL\Training\Logs\PPO_7
# -----------------------------
# | time/              |      |
# |    fps             | 556  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 381        |
# |    iterations           | 2          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00831252 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.686     |
# |    explained_variance   | 0.0069     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.26       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0193    |
# |    value_loss           | 53.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010864959 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.0996      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 33.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0078124944 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0176      |
# |    value_loss           | 53.9         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=205.60 +/- 109.95
# Episode length: 205.60 +/- 109.95
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 206        |
# |    mean_reward          | 206        |
# | time/                   |            |
# |    total_timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.00931197 |
# |    clip_fraction        | 0.0622     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.615     |
# |    explained_variance   | 0.332      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.9       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0132    |
# |    value_loss           | 61.7       |
# ----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 311   |
# |    iterations      | 5     |
# |    time_elapsed    | 32    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 6            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0053282576 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.597       |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 74.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 307          |
# |    iterations           | 7            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0052558146 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.379        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.01        |
# |    value_loss           | 71.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 8            |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0047599874 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.97         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00452     |
# |    value_loss           | 34.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 9            |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0052522672 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 20.7         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=469.60 +/- 41.23
# Episode length: 469.60 +/- 41.23
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 470          |
# |    mean_reward          | 470          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0024266206 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.45         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 35.8         |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 290   |
# |    iterations      | 10    |
# |    time_elapsed    | 70    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# Verbose controls the amount of info about the training displayed.

# %%
model_path = os.path.join('D:', 'RL', 'Training', 'Saved Models','best_model')
model = PPO.load(model_path, env = env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
evaluate_policy(model, env, n_eval_episodes = 10, render = True)
# Out:
# (9.6, 0.4898979485566356)

# %%
env.close()

# %% [markdown]
# # Changing Policies

# %%
net_arch = [dict(pi = [128, 128, 128, 128], vf = [128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs = {'net_arch' : net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps = 20000, callback = eval_callback)
# Out:
# Logging to D:RL\Training\Logs\DQN_4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3423     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3974     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4672     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 300      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4932     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 366      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5190     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 455      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 5882     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 596      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 5910     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 6003     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 809      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 5949     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 911      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.533    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5944     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 984      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5812     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5788     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.383    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 6021     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 6076     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.317    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 6049     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1438     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.282    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5918     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1512     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5684     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1619     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.177    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5524     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.134    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5448     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0985   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5393     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0519   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 5339     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 5300     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2090     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5192     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5096     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5102     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4870     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4804     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4758     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4758     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4755     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4741     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4738     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4761     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3112     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4808     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4808     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3273     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4836     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4861     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4880     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4918     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4971     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4992     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3777     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 5037     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 5092     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 5144     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 5173     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 5241     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 5285     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 5331     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 5357     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 5458     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 5500     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 5552     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 5602     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 5638     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 5675     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 5718     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 5725     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 5779     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 5788     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 5803     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 5837     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 5853     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 5856     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 5888     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 5883     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 5891     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 5868     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 5843     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 5777     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 5753     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 5710     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 5709     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 5674     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6780     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 5682     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 5606     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 5593     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 5570     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 5548     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 5530     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7256     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 5509     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 5445     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7416     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 5436     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 5392     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 5403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 5443     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 5447     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 5469     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 5501     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 5511     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 5526     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 5566     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 5561     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 5599     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8526     |
# ----------------------------------
# Eval num_timesteps=8560, episode_reward=9.60 +/- 0.80
# Episode length: 9.60 +/- 0.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 8560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 5494     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8586     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 5490     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 5474     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 5496     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8850     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 5518     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8931     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 5516     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 5523     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 5540     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 5542     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 5567     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 5601     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 5623     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 5652     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 5696     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 5689     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9858     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 5691     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 5742     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 5739     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 5756     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 5782     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 5786     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 5832     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 5837     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 5840     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 5844     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10721    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 5861     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 5920     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 5897     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 5932     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 5936     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 5930     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 5954     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 5975     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 5980     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 6018     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 6029     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 6012     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 6026     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 6037     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 6074     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 6063     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12191    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 6080     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 6100     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 6098     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 6099     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 6105     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 6097     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 6113     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 6129     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 6133     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 6144     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 6165     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 6174     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 6200     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 6187     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 6206     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 6212     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 6245     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13647    |
# ----------------------------------
# ...
# |    fps              | 6384     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 6384     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 6386     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 6395     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 6397     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 6422     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 6439     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 6429     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 6450     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 6437     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 6464     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 6499     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 6512     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 6517     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 6520     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 6535     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 6548     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 6562     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 6567     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 6596     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 6603     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 6599     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 6609     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 6617     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 6630     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 6639     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17644    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 6651     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 6670     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 6691     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 6677     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 6717     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 6716     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18246    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 6740     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 6749     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 6746     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18532    |
# ----------------------------------
# Eval num_timesteps=18560, episode_reward=9.60 +/- 0.49
# Episode length: 9.60 +/- 0.49
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 18560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 6731     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 6735     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 6749     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 6767     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 6767     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 6805     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 6791     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 6784     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 6809     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 6798     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 6799     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 6809     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19615    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 6820     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 6814     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 6838     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19914    |
# ----------------------------------

# %% [markdown]
# # Using an alternative Algorithm (DQN)

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps = 20000)
# Out:
# Logging to D:RL\Training\Logs\PPO_9
# -----------------------------
# | time/              |      |
# |    fps             | 557  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008692675 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00132    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.48        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008729233 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.0857      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 37.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0091022095 |
# |    clip_fraction        | 0.0901       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.628       |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.6         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0206      |
# |    value_loss           | 52.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008268418 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.324       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 60.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 6           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009455996 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 7           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004381199 |
# |    clip_fraction        | 0.0202      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00615    |
# |    value_loss           | 56.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 8           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003940847 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.95        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 41.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 9           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.001293776 |
# |    clip_fraction        | 0.00186     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.26        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 42.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 10           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0041683703 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 30.5         |
# ------------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes = 10, render = True)
# Out:
# (500.0, 0.0)

# %%
dqn_path = os.path.join('D:', 'RL', 'Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.save(dqn_path)
#
# NameError: name 'model' is not defined

# %%
env.close()
