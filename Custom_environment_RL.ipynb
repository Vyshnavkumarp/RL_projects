# %% [markdown]
# ## Import Dependencies

# %%
#Import GYM stuff
import gymnasium
from gymnasium import Env #--Superclass needed to build our own env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete #--Types of spaces available in gym

#Import helpers
import numpy as np
import random
import os

#Import stablebaselines stuff
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# WARNING:tensorflow:From C:\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Types of Spaces

# %% [markdown]
# ### Types of keys

# %%
Discrete(2).sample()
# Out:
# 0

# %%
Box(0, 1, shape = (3, 3)).sample()
# Out:
# array([[0.6645947 , 0.5390494 , 0.43508548],
#        [0.06009118, 0.65506786, 0.22427121],
#        [0.68648654, 0.5228779 , 0.6603348 ]], dtype=float32)

# %%
MultiBinary(4).sample()
# Out:
# array([0, 1, 1, 1], dtype=int8)

# %%
MultiDiscrete([4,2,3,1]).sample()
# Out:
# array([2, 0, 1, 0], dtype=int64)

# %%
# Stable_baseline3 doesn't support tuple
Tuple((Discrete(2), Box(0, 100, shape = (3,)))).sample()
# Out:
# (0, array([36.202244, 65.630196, 85.160934], dtype=float32))

# %%
Dict({'Height':Discrete(2), 'Speed':Box(0, 100, shape = (1,))}).sample()
# Out:
# OrderedDict([('Height', 0), ('Speed', array([43.644222], dtype=float32))])

# %% [markdown]
# ## Building an Environment
# - Build an agent to give us the best shower possible
# - Randomize temperature
# - 37 to 39 degree

# %%
# inheriting the Env class of gymnasium in the class of the environment that we are creating
class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=0, high=100, shape = (1,1))
        # Set start temp (which can be a value between 35 and 41
        self.state = 38 + random.randint(-3, 3)
        # Set shower length (length of an episode)
        self.shower_length = 60
    # step function is to apply action to the env and to return the result of the action
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action - 1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 

        # Truncate is used mention whether the episodes are truncated or not
        truncated = False
        
        # Calculate reward
        if self.state >= 37 and self.state <= 39: 
            reward = 1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Apply temperature noise
        # self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, truncated, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self, seed=None):
    # ... your environment initialization logic ...
        if seed is not None:
            # Use the seed to set a random state for your environment
            random.seed(seed)
            
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)
        # Reset shower time
        self.shower_length = 60 

        # the reset method need to return two argument
        info = {}
        # return the situation of the state which is the observation of the state
        return self.state, info

# %% [markdown]
# ## Test Environment

# %%
env = ShowerEnv()

# %%
env.observation_space.sample()
# Out:
# array([[53.85317]], dtype=float32)

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.reset()
# Out:
# (array([36.]), {})

# %%
episodes = 5
for episode in range(1, episodes + 1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        obs, reward, done, truncated, info = env.step(action)
        score += reward
    print("Episode: {}, Score: {}".format(episode, score))
env.close()
# Out:
# Episode: 1, Score: -38
# Episode: 2, Score: -58
# Episode: 3, Score: 32
# Episode: 4, Score: -16
# Episode: 5, Score: -42

# %% [markdown]
# ## Train Model

# %%
log_path = os.path.join('C:\\', 'Users', 'vyshn', 'Documents System', '6th Sem', 'RL', 'RL_Projects', 'Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
#!pip install shimmy>=0.2.1

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to C:\Users\vyshn\Documents System\6th Sem\RL\RL_Projects\Training\Logs\PPO_24
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -22.4    |
# | time/              |          |
# |    fps             | 738      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -22         |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010399518 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -8.51e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00887    |
# |    value_loss           | 85.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.3       |
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009388233 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -4.49e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 64.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25         |
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004879851 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.000592    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00084    |
# |    value_loss           | 70.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -23.2        |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 5            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0042462423 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.000347    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.8         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 6.44e-05     |
# |    value_loss           | 83.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -17.7       |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 6           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005887584 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.000145    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.000552    |
# |    value_loss           | 69.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -16.1        |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 7            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0037636473 |
# |    clip_fraction        | 0.0771       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.00206     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.7         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 72.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -14        |
# | time/                   |            |
# |    fps                  | 402        |
# |    iterations           | 8          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00875126 |
# |    clip_fraction        | 0.0949     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | -0.000878  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.3       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00874   |
# |    value_loss           | 59.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10.7        |
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 9            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0065144696 |
# |    clip_fraction        | 0.0944       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.000427     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.6         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 57.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -9.62       |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 10          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010934433 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 55.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -9.36        |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 11           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0075550787 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.0237      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.1         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 63.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -12.3       |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 12          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008021987 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00472    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 56.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -6.86        |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 13           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0051326947 |
# |    clip_fraction        | 0.0989       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.00062      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24           |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00568     |
# |    value_loss           | 56           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -3          |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 14          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010250151 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00123    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 42.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 4.34        |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 15          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007669637 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00431    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00736    |
# |    value_loss           | 45.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 6.42        |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 16          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008919814 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.00139    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00797    |
# |    value_loss           | 45.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 14.6        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 17          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011920338 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.00108     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 33.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 18          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012150878 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.000223    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.26        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 24          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 19          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010804362 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.000223   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00062    |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 32.4        |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 20          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011076734 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 6.66e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.000304    |
# |    value_loss           | 34.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 32.6        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 21          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012195095 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.000198    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 46.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 22          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012695159 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 5.64e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.4        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000788   |
# |    value_loss           | 43.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.5        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 23          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015872542 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 5.69e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00197     |
# |    value_loss           | 52.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39          |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 24          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.018849615 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 5.05e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.000237    |
# |    value_loss           | 58.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.9        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 25          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007015218 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 3.08e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00591     |
# |    value_loss           | 58.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.1        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 26          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.053041823 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | -1.05e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.01        |
# |    value_loss           | 63.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.8        |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 27          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009591409 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | -7.39e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00692     |
# |    value_loss           | 72.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.2        |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 28          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009961177 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | -8.34e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.01        |
# |    value_loss           | 71.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46          |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 29          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.016127698 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.977      |
# |    explained_variance   | 2.26e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.2        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0098      |
# |    value_loss           | 70.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.7        |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 30          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009560646 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.977      |
# |    explained_variance   | -4.17e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.6        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 76.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 47.8       |
# | time/                   |            |
# |    fps                  | 381        |
# |    iterations           | 31         |
# |    time_elapsed         | 166        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00918438 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.96      |
# |    explained_variance   | -3.7e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.3       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.00813    |
# |    value_loss           | 91.7       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 47.7         |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 32           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0088296365 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | -3.93e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.4         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00467      |
# |    value_loss           | 83           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.9        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 33          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009534692 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | 1.01e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.5        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00483     |
# |    value_loss           | 84.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.3        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 34          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.017360542 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 4.77e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.5        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0121      |
# |    value_loss           | 85.3        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 48.9      |
# | time/                   |           |
# |    fps                  | 382       |
# |    iterations           | 35        |
# |    time_elapsed         | 187       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0099516 |
# |    clip_fraction        | 0.196     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.922    |
# |    explained_variance   | -3.34e-06 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 50.6      |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0.00797   |
# |    value_loss           | 89.6      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 48.8       |
# | time/                   |            |
# |    fps                  | 382        |
# |    iterations           | 36         |
# |    time_elapsed         | 192        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02564726 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.926     |
# |    explained_variance   | -1.67e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.8       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.0103     |
# |    value_loss           | 86.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.4        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 37          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.017464017 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | -2.74e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00895     |
# |    value_loss           | 88.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.1        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 38          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011466131 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | -2.5e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00958     |
# |    value_loss           | 89.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.8        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 39          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.045946456 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00994     |
# |    value_loss           | 85.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.7        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 40          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010687083 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | -7.87e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.6        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00672     |
# |    value_loss           | 81.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 46.8       |
# | time/                   |            |
# |    fps                  | 382        |
# |    iterations           | 41         |
# |    time_elapsed         | 219        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.03262381 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.886     |
# |    explained_variance   | -1.85e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.7       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.0143     |
# |    value_loss           | 79.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.9         |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 42           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0113707725 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.877       |
# |    explained_variance   | -1.91e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.2         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.00795      |
# |    value_loss           | 87.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.5        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 43          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008941362 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.877      |
# |    explained_variance   | 4.47e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.7        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.000798    |
# |    value_loss           | 82.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 47.6       |
# | time/                   |            |
# |    fps                  | 383        |
# |    iterations           | 44         |
# |    time_elapsed         | 235        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03523518 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.892     |
# |    explained_variance   | 1.62e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 47.1       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.00508    |
# |    value_loss           | 83.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.6        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 45          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.020981612 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | 4.49e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.9        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 87.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.9        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 46          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.036590878 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 3.04e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.7        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0135      |
# |    value_loss           | 96.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.3        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 47          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018031484 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | -9.54e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.3        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 98.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 53.8       |
# | time/                   |            |
# |    fps                  | 383        |
# |    iterations           | 48         |
# |    time_elapsed         | 256        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02193769 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.886     |
# |    explained_variance   | 1.49e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.1       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0123     |
# |    value_loss           | 101        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 53.8         |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 49           |
# |    time_elapsed         | 261          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0143724885 |
# |    clip_fraction        | 0.224        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | 4.17e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.8         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.0138       |
# |    value_loss           | 104          |
# ------------------------------------------

# %% [markdown]
# ## Save Model

# %%
shower_path = os.path.join('C:\\', 'Users', 'vyshn', 'Documents System', '6th Sem', 'RL', 'RL_Projects', 'Training', 'Saved Models', 'Shower_Model_PPO')

# %%
model.save(shower_path)

# %%
del model

# %%
model = PPO.load(shower_path, env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
evaluate_policy(model, env, n_eval_episodes=10, render = False)
# Out:
# (59.2, 0.9797958971132712)
